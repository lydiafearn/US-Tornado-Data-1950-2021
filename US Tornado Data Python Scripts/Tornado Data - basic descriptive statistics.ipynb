# %% [markdown]
# # US Tornado data - basic descriptive statistics

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import dataset
path = r'C:\Users\lydia\OneDrive\Documents\Career Foundry Data\Data Immersion\Acheivement 6'
df = pd.read_csv(os.path.join(path, 'Prepared Data', 'Tornado Data.csv'), index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0  year  month  day        date    states  mag  injuries  deaths  \
# 0           0  1950      1    3  1950-01-03  Illinois  3.0         3       0
# 1           1  1950      1    3  1950-01-03  Missouri  3.0         3       0
# 2           2  1950      1    3  1950-01-03      Ohio  1.0         1       0
# 3           3  1950      1   13  1950-01-13  Arkansas  3.0         1       1
# 4           4  1950      1   25  1950-01-25  Illinois  2.0         0       0
#
#    starting lat  starting lon  ending lat  ending lon  length in miles  \
# 0         39.10        -89.30       39.12      -89.23              3.6
# 1         38.77        -90.22       38.83      -90.03              9.5
# 2         40.88        -84.58        0.00        0.00              0.1
# 3         34.40        -94.37        0.00        0.00              0.6
# 4         41.17        -87.33        0.00        0.00              0.1
#
#    width in yards
# 0             130
# 1             150
# ...

# %%
# Remove unnamed column
df = df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ## Basic Descriptive Statistical Testing

# %%
df.describe()
# Out:
#                year         month           day           mag      injuries  \
# count  67096.000000  67096.000000  67096.000000  66491.000000  67096.000000
# mean    1991.427090      5.975751     15.928103      0.781640      1.447344
# std       19.323831      2.443085      8.739900      0.898359     18.326231
# min     1950.000000      1.000000      1.000000      0.000000      0.000000
# 25%     1976.000000      4.000000      8.000000      0.000000      0.000000
# 50%     1994.000000      6.000000     16.000000      1.000000      0.000000
# 75%     2008.000000      7.000000     24.000000      1.000000      0.000000
# max     2021.000000     12.000000     31.000000      5.000000   1740.000000
#
#              deaths  starting lat  starting lon    ending lat    ending lon  \
# count  67096.000000  67096.000000  67096.000000  67096.000000  67096.000000
# mean       0.091093     37.140897    -92.745491     22.819001    -56.456826
# ...
